# %%
import pandas as pd

# %%
data = pd.read_csv("../dataset/traffic_violations_cleaned.csv")
data.head(2)
# Out:
#                                   SeqID     Stop_dateTime   Month   Weekday  \
# 0  b66f253b-af29-4bc4-bb73-93755ca2a779  31-08-2023 16:41  August  Thursday
# 1  b66f253b-af29-4bc4-bb73-93755ca2a779  31-08-2023 16:41  August  Thursday
#
#    Hour  TimeOfDay Violation_category Violation Type      Charge  \
# 0    16  Afternoon            LICENSE       Citation  16-101(A1)
# 1    16  Afternoon       REGISTRATION       Citation   13-409(B)
#
#                 Location_clean  ...  Accident  Personal Injury  \
# 0  OAKMONT AVE / GROVEMONT CIR  ...     False            False
# 1  OAKMONT AVE / GROVEMONT CIR  ...     False            False
#
#   Property Damage  Fatal Contributed To Accident Alcohol  Belts Work Zone  \
# 0           False  False                   False   False  False     False
# 1           False  False                   False   False  False     False
#
#   Search Conducted ArrestTypeCategory
# 0               No      Marked Patrol
# 1               No      Marked Patrol
#
# ...

# %%
data['TimeOfDay'].head(4)
# Out:
# 0    Afternoon
# 1    Afternoon
# 2    Afternoon
# 3    Afternoon
# Name: TimeOfDay, dtype: str

# %%
data.columns
# Out:
# Index(['SeqID', 'Stop_dateTime', 'Month', 'Weekday', 'Hour', 'TimeOfDay',
#        'Violation_category', 'Violation Type', 'Charge', 'Location_clean',
#        'Latitude', 'Longitude', 'State', 'Race', 'Gender', 'Driver City',
#        'Driver State', 'DL State', 'VehicleCategory', 'Make', 'Model', 'Year',
#        'Color', 'Accident', 'Personal Injury', 'Property Damage', 'Fatal',
#        'Contributed To Accident', 'Alcohol', 'Belts', 'Work Zone',
#        'Search Conducted', 'ArrestTypeCategory'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   SeqID                    1048575 non-null  str
#  1   Stop_dateTime            1048575 non-null  datetime64[us]
#  2   Month                    1048575 non-null  str
#  3   Weekday                  1048575 non-null  str
#  4   Hour                     1048575 non-null  int64
#  5   TimeOfDay                1048575 non-null  str
#  6   Violation_category       1048575 non-null  str
#  7   Violation Type           1048575 non-null  str
#  8   Charge                   1048575 non-null  str
#  9   Location_clean           1048574 non-null  str
#  10  Latitude                 1048575 non-null  float64
#  11  Longitude                1048575 non-null  float64
#  12  State                    1048575 non-null  str
#  13  Race                     1048575 non-null  str
# ...

# %%
data['Stop_dateTime'] = pd.to_datetime(
    data['Stop_dateTime'],
    dayfirst=True
)

# %%
data['SeqID'].duplicated().sum()
# Out:
# 466032

# %%
print(data['Stop_dateTime'].iloc[0])
print(type(data['Stop_dateTime'].iloc[0]))
# Out:
# 2023-08-31 16:41:00
# <class 'pandas.Timestamp'>

# %%
data['Stop_dateTime'] = pd.to_datetime(
    data['Stop_dateTime'],
    format='%d-%m-%Y %H:%M'
)

# %%
data.columns
# Out:
# Index(['SeqID', 'Stop_dateTime', 'Month', 'Weekday', 'Hour', 'TimeOfDay',
#        'Violation_category', 'Violation Type', 'Charge', 'Location_clean',
#        'Latitude', 'Longitude', 'State', 'Race', 'Gender', 'Driver City',
#        'Driver State', 'DL State', 'VehicleCategory', 'Make', 'Model', 'Year',
#        'Color', 'Accident', 'Personal Injury', 'Property Damage', 'Fatal',
#        'Contributed To Accident', 'Alcohol', 'Belts', 'Work Zone',
#        'Search Conducted', 'ArrestTypeCategory'],
#       dtype='str')

# %%
data['Violation Type'].value_counts()
# Out:
# Violation Type
# Citation    768574
# Warning     270876
# ESERO         9047
# SERO            78
# Name: count, dtype: int64

# %%
data['Accident'].value_counts()
# Out:
# Accident
# False    1003902
# True       44673
# Name: count, dtype: int64

# %%
data['Violation Type'].value_counts()
# Out:
# Violation Type
# Citation    768574
# Warning     270876
# ESERO         9047
# SERO            78
# Name: count, dtype: int64
